# %%
from PIL import Image

# %%
# 读取图像并将其转换为灰度图像
pil_im = Image.open('D:\\桌面\\1.jpg')
pil_im.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=1440x1920 at 0x52A3BE0>

# %%
# 1.1.1 转换图像格式
## 通过save方法可以将图像保存为多种格式的文件，

# %%
# 从文件名列表读取所有图像文件，并转换为jpeg格式
# 通过save方法可以将图像保存为多种格式的文件
from PIL import Image
import os
for infile in  filelist：
    outfile = os.path.splitext(infile)[0] + ".jpg"
    if infile != outfile:
        try:
            Image.open(infile).save(outfile)
        except IOError:
            print("cannot convert")
# Out:
#   File "<ipython-input-8-0c1fb3d808a3>", line 5
#     for infile in  filelist：
#                            ^
# SyntaxError: invalid character in identifier

# %%
pil_im.thumbnail((128,128))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-30a043331b4a> in <module>()
# ----> 1 pil_im.thumbnail((128,128)).imshow()
#
# AttributeError: 'NoneType' object has no attribute 'imshow'
